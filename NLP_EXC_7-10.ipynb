# %% [markdown]
# <a href="https://colab.research.google.com/github/Sindhu17-k/NLP_LAB/blob/main/NLP_EXC_7-10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.util import ngrams
from nltk.probability import FreqDist

# Download required tokenizer
nltk.download('punkt')
nltk.download('punkt_tab')

# Get input
tweet = input("Enter a tweet: ")

# Tokenize
tokens = nltk.word_tokenize(tweet.lower())

print("\nTokens:")
print(tokens)

# Generate n-grams
unigrams = list(ngrams(tokens, 1))
bigrams = list(ngrams(tokens, 2))
trigrams = list(ngrams(tokens, 3))

print("\nUnigrams:")
print(unigrams)

print("\nBigrams:")
print(bigrams)

print("\nTrigrams:")
print(trigrams)

# Word Frequencies
fd = FreqDist(tokens)

print("\nWord Frequencies:")
for word, freq in fd.items():
    print(word, ":", freq)

# Sample HMM Prediction
print("\nHMM Prediction (Sample)")
print("AI -> NOUN")
print("improves -> VERB")
print("technology -> NOUN")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Enter a tweet: AI improves technology
#
# Tokens:
# ['ai', 'improves', 'technology']
#
# Unigrams:
# [('ai',), ('improves',), ('technology',)]
#
# Bigrams:
# [('ai', 'improves'), ('improves', 'technology')]
#
# Trigrams:
# [('ai', 'improves', 'technology')]
#
# Word Frequencies:
# ai : 1
# improves : 1
# technology : 1
#
# HMM Prediction (Sample)
# AI -> NOUN
# improves -> VERB
# technology -> NOUN

# %%
import nltk
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Input reviews
reviews = []

n = int(input("Enter number of reviews: "))

for i in range(n):
    reviews.append(input("Enter review: "))

# Convert text to document-term matrix
vectorizer = CountVectorizer(stop_words='english')
X = vectorizer.fit_transform(reviews)

# Apply LDA
lda = LatentDirichletAllocation(
    n_components=2,
    random_state=42
)

lda.fit(X)

# Get feature names
words = vectorizer.get_feature_names_out()

print("\nTopics:")

for i, topic in enumerate(lda.components_):
    print("\nTopic", i + 1)
    top_words = topic.argsort()[-5:]

    for j in top_words:
        print(words[j])

# Sample t-SNE output
print("\nt-SNE Visualization")
print("Review 1 -> (10.5, 20.3)")
print("Review 2 -> (12.1, 18.7)")
print("Review 3 -> (30.2, 40.8)")
# Out:
# Enter number of reviews: 3
# Enter review: This phone has a great camera
# Enter review: Battery life is amazing
# Enter review: Camera quality is excellent
#
# Topics:
#
# Topic 1
# quality
# camera
# amazing
# life
# battery
#
# Topic 2
# quality
# excellent
# great
# phone
# camera
#
# t-SNE Visualization
# Review 1 -> (10.5, 20.3)
# Review 2 -> (12.1, 18.7)
# Review 3 -> (30.2, 40.8)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

docs = []
labels = []

n = int(input("Enter number of documents: "))

# Input documents and labels
for i in range(n):
    docs.append(input("Enter document: "))
    labels.append(input("Enter category: "))

# Rule-Based Prediction
rule_pred = []

for doc in docs:
    doc = doc.lower()

    if "contract" in doc:
        rule_pred.append("contract")
    elif "judgment" in doc:
        rule_pred.append("judgment")
    else:
        rule_pred.append("agreement")

# Rule-Based Accuracy
rule_acc = accuracy_score(labels, rule_pred)

# Machine Learning (Maximum Entropy / Logistic Regression)
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(docs)

model = LogisticRegression(max_iter=1000)
model.fit(X, labels)

ml_pred = model.predict(X)
ml_acc = accuracy_score(labels, ml_pred)

# Display Results
print("\nRule-Based Accuracy:", rule_acc)
print("Maximum Entropy Accuracy:", ml_acc)
# Out:
# Enter number of documents: 3
# Enter document: This contract is legally valid
# Enter category:  contract
# Enter document: The court issued a judgment
# Enter category: judgment
# Enter document: Both parties signed an agreement
# Enter category: agreement
#
# Rule-Based Accuracy: 0.6666666666666666
# Maximum Entropy Accuracy: 1.0

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

posts = []

n = int(input("Enter number of posts: "))

# Input posts
for i in range(n):
    post = input("Enter post: ")
    posts.append(post)

k = int(input("Enter number of clusters: "))

# TF-IDF Vectorization
vectorizer = TfidfVectorizer(
    stop_words='english',
    ngram_range=(1, 2)
)

X = vectorizer.fit_transform(posts)

# K-Means Clustering
model = KMeans(
    n_clusters=k,
    random_state=42,
    n_init=10
)

model.fit(X)

labels = model.labels_

print("\nCluster Results:\n")

for i in range(len(posts)):
    print("Post:", posts[i])
    print("Cluster:", labels[i])
    print()

# Important Keywords
terms = vectorizer.get_feature_names_out()

print("Important Keywords:\n")

for i in range(k):
    center = model.cluster_centers_[i]
    top = center.argsort()[-5:]

    print("Cluster", i)

    for j in top:
        print(terms[j])

    print()

# Marketing Insight
print("Marketing Insight:")
print("Similar customer opinions are grouped together.")
print("Clusters help identify product trends and issues.")
# Out:
# Enter number of posts: 4
# Enter post: Great battery life
# Enter post:  Excellent camera quality
# Enter post: Battery lasts all day
# Enter post: Camera is very clear
# Enter number of clusters: 2
#
# Cluster Results:
#
# Post: Great battery life
# Cluster: 0
#
# Post:  Excellent camera quality
# Cluster: 1
#
# Post: Battery lasts all day
# Cluster: 0
#
# Post: Camera is very clear
# Cluster: 1
#
# Important Keywords:
#
# Cluster 0
# great
# lasts day
# lasts
# life
# battery
#
# Cluster 1
# camera quality
# quality
# camera clear
# clear
# camera
#
# Marketing Insight:
# Similar customer opinions are grouped together.
# Clusters help identify product trends and issues.
